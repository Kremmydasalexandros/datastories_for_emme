# %% [markdown]
# <a href="https://colab.research.google.com/github/Kremmydasalexandros/datastories_for_emme/blob/main/%CE%93%CE%A5%CE%9D%CE%91%CE%99%CE%9A%CE%9F%CE%9A%CE%A4%CE%9F%CE%9D%CE%99%CE%91_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m spacy download el_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 22.3 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('el_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import glob
from sklearn.feature_extraction.text import CountVectorizer
from datetime import datetime

# %%
filepath = "/content/gdrive/MyDrive/GYNAIKOKTONIA.csv"

# %%
df = pd.read_csv("/content/gdrive/MyDrive/GYNAIKOKTONIA.csv")
df
# Out:
#      type            source  \
# 0     web      athina984.gr
# 1     web    kathimerini.gr
# 2     web     athlosnews.gr
# 3     web        youfly.com
# 4     web             in.gr
# ...   ...               ...
# 1448  web       coollife.gr
# 1449  web  karditsalive.net
# 1450  web          znews.gr
# 1451  web         enikos.gr
# 1452  web   dekeleianews.gr
#
#                                                   title  \
# 0     Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# 1                       Τα διδάγματα και η προτροπή μου
# 2     Ποινή φυλάκισης 12 μηνών αλλά εξαγοράσιμη στον...
# 3     Το Προξενιό της Ιουλίας: Ο Προβιός στο χώμα κα...
# 4     Εκλογές στο Ιράν: Θα αλλάξουν οι σχέσεις με τι...
# ...                                                 ...
# 1448  Σοφία Πολυζωγοπούλου – Η σύζυγος του Απόστολου...
# 1449  Το Σάββατο 29 Ιουνίου το 40ήμερο μνημόσυνο της...
# 1450  Φωτεινή Ντεμίρη: «Είμαι κατά του γάμου, αν ήτα...
# ...

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df = df.reset_index(drop=True)

# %%
df.tail(1)
# Out:
#      type           source                                              title  \
# 1435  web  dekeleianews.gr  Ιταλία: Παράνομος αλλοδαπός βίασε και σκότωσε ...
#
#                                                    text     categories  \
# 1435  Οι Αρχές της Ιταλίας ερευνούν την άγρια δολοφο...  ΓΥΝΑΙΚΟΚΤΟΝΙΑ
#
#      sentiment  impact        date      time  \
# 1435  Negative    40.0  2024-06-27  22:00:12
#
#                                                    link
# 1435  https://dekeleianews.gr/2024/06/27/%ce%b9%cf%8...

# %%
df['full_text'] = df[['title', 'text']].agg(' '.join, axis=1)

# %%
selected_cols_df = df[["title", "text"]]
selected_cols_df.tail(1)
# Out:
#                                                   title  \
# 1435  Ιταλία: Παράνομος αλλοδαπός βίασε και σκότωσε ...
#
#                                                    text
# 1435  Οι Αρχές της Ιταλίας ερευνούν την άγρια δολοφο...

# %%
selected_cols_df.to_csv("/content/gdrive/MyDrive/gunaikoktonia1.csv", index=False)
#df.to_csv("<folder/path/desirable_filename.csv>", index=False)

# %%
df = pd.read_csv("/content/gdrive/MyDrive/gunaikoktonia1.csv")
df.tail(1)
# Out:
#                                                   title  \
# 1435  Ιταλία: Παράνομος αλλοδαπός βίασε και σκότωσε ...
#
#                                                    text
# 1435  Οι Αρχές της Ιταλίας ερευνούν την άγρια δολοφο...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import spacy

# %%
nlp = spacy.load('el_core_news_sm')

# %%
len(list(nlp.Defaults.stop_words))
# Out:
# 663

# %%
import pandas as pd

# %%
emolex_csv_path = "/content/gdrive/MyDrive/gunaikoktonia1.csv"
emolex_df = pd.read_csv(emolex_csv_path)
emolex_df.tail(1)
# Out:
#                                                   title  \
# 1435  Ιταλία: Παράνομος αλλοδαπός βίασε και σκότωσε ...
#
#                                                    text
# 1435  Οι Αρχές της Ιταλίας ερευνούν την άγρια δολοφο...

# %%
positive_words_df = emolex_df[emolex_df.Positive == 1][['word']]

positive_words_df = positive_words_df.rename(columns={"word":"positive_words"}).reset_index(drop=True)


negative_words_df = emolex_df[emolex_df.Negative == 1][['word']]

negative_words_df = negative_words_df.rename(columns={"word":"negative_words"}).reset_index(drop=True)



joy_words_df = emolex_df[emolex_df.Joy == 1][['word']]

joy_words_df = joy_words_df.rename(columns={"word":"joy_words"}).reset_index(drop=True)


sadness_words_df = emolex_df[emolex_df.Sadness == 1][['word']]

sadness_words_df = sadness_words_df.rename(columns={"word":"sadness_words"}).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-92511ae3b1c6> in <cell line: 1>()
# ----> 1 positive_words_df = emolex_df[emolex_df.Positive == 1][['word']]
#       2
#       3 positive_words_df = positive_words_df.rename(columns={"word":"positive_words"}).reset_index(drop=True)
#       4
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Positive'
