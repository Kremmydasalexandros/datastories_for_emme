# %% [markdown]
# <a href="https://colab.research.google.com/github/Kremmydasalexandros/datastories_for_emme/blob/main/%CE%93%CE%A5%CE%9D%CE%91%CE%99%CE%9A%CE%9F%CE%9A%CE%A4%CE%9F%CE%9D%CE%99%CE%91_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/gdrive/MyDrive/GYNAIKOKTONIA.csv")

# %%
df
# Out:
#      type            source  \
# 0     web      athina984.gr
# 1     web    kathimerini.gr
# 2     web     athlosnews.gr
# 3     web        youfly.com
# 4     web             in.gr
# ...   ...               ...
# 1448  web       coollife.gr
# 1449  web  karditsalive.net
# 1450  web          znews.gr
# 1451  web         enikos.gr
# 1452  web   dekeleianews.gr
#
#                                                   title  \
# 0     Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# 1                       Τα διδάγματα και η προτροπή μου
# 2     Ποινή φυλάκισης 12 μηνών αλλά εξαγοράσιμη στον...
# 3     Το Προξενιό της Ιουλίας: Ο Προβιός στο χώμα κα...
# 4     Εκλογές στο Ιράν: Θα αλλάξουν οι σχέσεις με τι...
# ...                                                 ...
# 1448  Σοφία Πολυζωγοπούλου – Η σύζυγος του Απόστολου...
# 1449  Το Σάββατο 29 Ιουνίου το 40ήμερο μνημόσυνο της...
# 1450  Φωτεινή Ντεμίρη: «Είμαι κατά του γάμου, αν ήτα...
# ...

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df = df.reset_index(drop=True)

# %%
df
# Out:
#      type            source  \
# 0     web      athina984.gr
# 1     web    kathimerini.gr
# 2     web     athlosnews.gr
# 3     web        youfly.com
# 4     web             in.gr
# ...   ...               ...
# 1431  web      ieidiseis.gr
# 1432  web  karditsalive.net
# 1433  web          znews.gr
# 1434  web         enikos.gr
# 1435  web   dekeleianews.gr
#
#                                                   title  \
# 0     Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# 1                       Τα διδάγματα και η προτροπή μου
# 2     Ποινή φυλάκισης 12 μηνών αλλά εξαγοράσιμη στον...
# 3     Το Προξενιό της Ιουλίας: Ο Προβιός στο χώμα κα...
# 4     Εκλογές στο Ιράν: Θα αλλάξουν οι σχέσεις με τι...
# ...                                                 ...
# 1431  Τροιζήνα: Παιδί σκοτώθηκε στο φαράγγι Διαβολογ...
# 1432  Το Σάββατο 29 Ιουνίου το 40ήμερο μνημόσυνο της...
# 1433  Φωτεινή Ντεμίρη: «Είμαι κατά του γάμου, αν ήτα...
# ...

# %%
df["date"].max()
# Out:
# '2024-06-28'

# %%
import pandas as pd




df['date'] = pd.to_datetime(df['date'])

arthra_27_iouniou = df[df['date'] == '2024-06-27']


arthra_27_iouniou = arthra_27_iouniou.shape[0]
print(f' {arthra_27_iouniou}')
# Out:
#  104

# %%
arthra_28_iouniou = df[df['date'] == '2024-06-28']


arthra_28_iouniou = arthra_28_iouniou.shape[0]
print(f' {arthra_28_iouniou}')
# Out:
#  1332

# %%
df.head(779)
# Out:
#     type           source                                              title  \
# 0    web     athina984.gr  Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# 1    web   kathimerini.gr                    Τα διδάγματα και η προτροπή μου
# 2    web    athlosnews.gr  Ποινή φυλάκισης 12 μηνών αλλά εξαγοράσιμη στον...
# 3    web       youfly.com  Το Προξενιό της Ιουλίας: Ο Προβιός στο χώμα κα...
# 4    web            in.gr  Εκλογές στο Ιράν: Θα αλλάξουν οι σχέσεις με τι...
# ..   ...              ...                                                ...
# 774  web         tanea.gr     Απόστολος Λύτρας: Κατέθεσε αίτημα αποφυλάκισης
# 775  web           cnn.gr    Αίτημα αποφυλάκισης κατέθεσε ο Απόστολος Λύτρας
# 776  web  toaerodromio.gr    Αίτημα αποφυλάκισης κατέθεσε ο Απόστολος Λύτρας
# 777  web    tromaktiko.gr    Αίτημα αποφυλάκισης κατέθεσε ο Απόστολος Λύτρας
# 778  web         tanea.gr  Απόστολος Λύτρας: Η ατάκα που «καίει» τον ποιν...
#
# ...

# %%
df.loc[778, 'title']
# Out:
# 'Απόστολος Λύτρας: Η ατάκα που «καίει» τον ποινικολόγο – «Έχω χτυπήσει τη Σοφία, ελπίζω να μην μπλέξω»'

# %%
df.head(590)
# Out:
#     type                source  \
# 0    web          athina984.gr
# 1    web        kathimerini.gr
# 2    web         athlosnews.gr
# 3    web            youfly.com
# 4    web                 in.gr
# ..   ...                   ...
# 585  web       parapolitika.gr
# 586  web            debater.gr
# 587  web       parapolitika.gr
# 588  web  dikastikoreportaz.gr
# 589  web            alphatv.gr
#
#                                                  title  \
# 0    Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# 1                      Τα διδάγματα και η προτροπή μου
# 2    Ποινή φυλάκισης 12 μηνών αλλά εξαγοράσιμη στον...
# 3    Το Προξενιό της Ιουλίας: Ο Προβιός στο χώμα κα...
# 4    Εκλογές στο Ιράν: Θα αλλάξουν οι σχέσεις με τι...
# ..                                                 ...
# 585  Τζιλ Μπάιντεν: Κριτική στα social media για το...
# 586  «Έχω χτυπήσει άσχημα τη Σοφία, ελπίζω να μην μ...
# 587  Το τελευταίο ανατρεπτικό “Φως στο Τούνελ” της ...
# ...

# %%
df.head(79)
# Out:
#    type          source                                              title  \
# 0   web    athina984.gr  Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# 1   web  kathimerini.gr                    Τα διδάγματα και η προτροπή μου
# 2   web   athlosnews.gr  Ποινή φυλάκισης 12 μηνών αλλά εξαγοράσιμη στον...
# 3   web      youfly.com  Το Προξενιό της Ιουλίας: Ο Προβιός στο χώμα κα...
# 4   web           in.gr  Εκλογές στο Ιράν: Θα αλλάξουν οι σχέσεις με τι...
# ..  ...             ...                                                ...
# 74  web  lesvosnews.net  17.800 μόρια συγκέντρωσε ο Μπάμπης Αναγνωστόπο...
# 75  web      alphatv.gr  Νέες βαριές καταγγελίες κατά του Απόστολου Λύτ...
# 76  web   tilestwra.com  Πανελλαδικές 2024: Ζευγάρι από τον Βόλο, έδωσε...
# 77  web   protothema.gr  Τάσος Χαλκιάς: Πώς είναι δυνατόν να εκδηλώνεις...
# 78  web       oknews.gr  Δημοσιογράφος ΕΡΤ στη δίκη για τον ξυλοδαρμό τ...
#
# ...

# %%
df.loc[77, 'title']
# Out:
# 'Τάσος Χαλκιάς: Πώς είναι δυνατόν να εκδηλώνεις τέτοια μορφή βίας ενάντια στη γυναίκα σου, στη μάνα των παιδιών σου;'
