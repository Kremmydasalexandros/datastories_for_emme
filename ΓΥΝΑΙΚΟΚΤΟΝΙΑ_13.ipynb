# %% [markdown]
# <a href="https://colab.research.google.com/github/Kremmydasalexandros/datastories_for_emme/blob/main/%CE%93%CE%A5%CE%9D%CE%91%CE%99%CE%9A%CE%9F%CE%9A%CE%A4%CE%9F%CE%9D%CE%99%CE%91_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv("/content/gdrive/MyDrive/GYNAIKOKTONIA.csv")
df
# Out:
#      type            source  \
# 0     web      athina984.gr
# 1     web    kathimerini.gr
# 2     web     athlosnews.gr
# 3     web        youfly.com
# 4     web             in.gr
# ...   ...               ...
# 1448  web       coollife.gr
# 1449  web  karditsalive.net
# 1450  web          znews.gr
# 1451  web         enikos.gr
# 1452  web   dekeleianews.gr
#
#                                                   title  \
# 0     Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# 1                       Τα διδάγματα και η προτροπή μου
# 2     Ποινή φυλάκισης 12 μηνών αλλά εξαγοράσιμη στον...
# 3     Το Προξενιό της Ιουλίας: Ο Προβιός στο χώμα κα...
# 4     Εκλογές στο Ιράν: Θα αλλάξουν οι σχέσεις με τι...
# ...                                                 ...
# 1448  Σοφία Πολυζωγοπούλου – Η σύζυγος του Απόστολου...
# 1449  Το Σάββατο 29 Ιουνίου το 40ήμερο μνημόσυνο της...
# 1450  Φωτεινή Ντεμίρη: «Είμαι κατά του γάμου, αν ήτα...
# ...

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df = df.reset_index(drop=True)

# %%
df
# Out:
#      type            source  \
# 0     web      athina984.gr
# 1     web    kathimerini.gr
# 2     web     athlosnews.gr
# 3     web        youfly.com
# 4     web             in.gr
# ...   ...               ...
# 1431  web      ieidiseis.gr
# 1432  web  karditsalive.net
# 1433  web          znews.gr
# 1434  web         enikos.gr
# 1435  web   dekeleianews.gr
#
#                                                   title  \
# 0     Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# 1                       Τα διδάγματα και η προτροπή μου
# 2     Ποινή φυλάκισης 12 μηνών αλλά εξαγοράσιμη στον...
# 3     Το Προξενιό της Ιουλίας: Ο Προβιός στο χώμα κα...
# 4     Εκλογές στο Ιράν: Θα αλλάξουν οι σχέσεις με τι...
# ...                                                 ...
# 1431  Τροιζήνα: Παιδί σκοτώθηκε στο φαράγγι Διαβολογ...
# 1432  Το Σάββατο 29 Ιουνίου το 40ήμερο μνημόσυνο της...
# 1433  Φωτεινή Ντεμίρη: «Είμαι κατά του γάμου, αν ήτα...
# ...

# %%
df.date.min(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     512         try:
# --> 513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
#
# KeyError: 3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ad4e8211e60d> in <cell line: 1>()
# ----> 1 df.date.min(3)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in min(self, axis, skipna, numeric_only, **kwargs)
#   11667             **kwargs,
#   11668         ):
# > 11669             return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11670
#   11671         setattr(cls, "min", min)
#
# ...

# %%
df['datetime'] = pd.to_datetime(df['date'] + ' ' + df['time'])

# %%
df_sorted = df.sort_values(by='datetime')

# %%
df_sorted.iloc[-1]
# Out:
# type                                                        web
# source                                             athina984.gr
# title         Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# text          Στη Θεσσαλονίκη, στο Θέατρο Γης, στην μεγάλη σ...
# categories                                        ΓΥΝΑΙΚΟΚΤΟΝΙΑ
# sentiment                                              Positive
# impact                                                   76.834
# date                                                 2024-06-28
# time                                                   22:38:01
# link          https://athina984.gr/2024/06/28/omilia-koytsoy...
# datetime                                    2024-06-28 22:38:01
# Name: 0, dtype: object

# %%
df_sorted.iloc[0]
# Out:
# type                                                        web
# source                                          dekeleianews.gr
# title         Ιταλία: Παράνομος αλλοδαπός βίασε και σκότωσε ...
# text          Οι Αρχές της Ιταλίας ερευνούν την άγρια δολοφο...
# categories                                        ΓΥΝΑΙΚΟΚΤΟΝΙΑ
# sentiment                                              Negative
# impact                                                     40.0
# date                                                 2024-06-27
# time                                                   22:00:12
# link          https://dekeleianews.gr/2024/06/27/%ce%b9%cf%8...
# datetime                                    2024-06-27 22:00:12
# Name: 1435, dtype: object
