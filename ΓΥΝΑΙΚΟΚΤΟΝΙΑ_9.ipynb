# %% [markdown]
# <a href="https://colab.research.google.com/github/Kremmydasalexandros/datastories_for_emme/blob/main/%CE%93%CE%A5%CE%9D%CE%91%CE%99%CE%9A%CE%9F%CE%9A%CE%A4%CE%9F%CE%9D%CE%99%CE%91_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import spacy
import numpy

# %%
from google.colab import drive
drive.mount ('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import glob

# %%
df = pd.read_csv("/content/gdrive/MyDrive/sentimentanalysis3.csv>")
df
# Out:
#                                                   title  \
# 0     Ομιλία Κουτσούμπα στη συναυλία-αφιέρωμα στο πο...
# 1                       Τα διδάγματα και η προτροπή μου
# 2     Ποινή φυλάκισης 12 μηνών αλλά εξαγοράσιμη στον...
# 3     Το Προξενιό της Ιουλίας: Ο Προβιός στο χώμα κα...
# 4     Εκλογές στο Ιράν: Θα αλλάξουν οι σχέσεις με τι...
# ...                                                 ...
# 1431  Τροιζήνα: Παιδί σκοτώθηκε στο φαράγγι Διαβολογ...
# 1432  Το Σάββατο 29 Ιουνίου το 40ήμερο μνημόσυνο της...
# 1433  Φωτεινή Ντεμίρη: «Είμαι κατά του γάμου, αν ήτα...
# 1434  Φυλακές Κορυδαλλού: Η ανακοίνωση του υπουργείο...
# 1435  Ιταλία: Παράνομος αλλοδαπός βίασε και σκότωσε ...
#
#                                                    text  positivity  \
# 0     Στη Θεσσαλονίκη, στο Θέατρο Γης, στην μεγάλη σ...         106
# 1     Ι. Παλαμίδης*\nΚύριε διευθυντά\nΔιαβάζοντας όπ...          17
# 2     Με ποινή φυλάκισης 12 μηνών εξαγοράσιμη προς 1...          23
# ...
